# %% [markdown]
# <a href="https://colab.research.google.com/github/CauaMaia/processamento_de_imagens/blob/main/Aula07_08_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
import cv2
from google.colab.patches import cv2_imshow

# %%
arquivos = files.upload()
# Out:
#      <input type="file" id="files-bcdc415f-deb8-4527-956c-b7428af2b88f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bcdc415f-deb8-4527-956c-b7428af2b88f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
img = cv2.imread('luva.jpg')
cv2_imshow(img)
img
# Out:
# <PIL.Image.Image image mode=RGB size=495x619>
# array([[[188, 176, 158],
#         [188, 176, 158],
#         [188, 176, 158],
#         ...,
#         [195, 163,  90],
#         [195, 163,  90],
#         [195, 163,  90]],
#
#        [[188, 176, 158],
#         [188, 176, 158],
#         [188, 176, 158],
#         ...,
#         [195, 163,  90],
#         [195, 163,  90],
#         [195, 163,  90]],
#
#        [[188, 176, 158],
#         [188, 176, 158],
#         [188, 176, 158],
#         ...,
#         [195, 163,  90],
#         [195, 163,  90],
#         [195, 163,  90]],
#
#        ...,
#
#        [[ 33,  58, 132],
#         [ 33,  58, 132],
#         [ 32,  57, 131],
#         ...,
#         [ 16,  42, 109],
#         [ 16,  42, 109],
#         [ 16,  42, 109]],
#
#        [[ 33,  58, 132],
#         [ 33,  58, 132],
#         [ 32,  57, 131],
#         ...,
#         [ 16,  42, 109],
#         [ 16,  42, 109],
#         [ 16,  42, 109]],
#
#        [[ 33,  58, 132],
# ...

# %%
img.shape
# Out:
# (619, 495, 3)

# %%
print(img)
# Out:
# [[[188 176 158]
#   [188 176 158]
#   [188 176 158]
#   ...
#   [195 163  90]
#   [195 163  90]
#   [195 163  90]]
#
#  [[188 176 158]
#   [188 176 158]
#   [188 176 158]
#   ...
#   [195 163  90]
#   [195 163  90]
#   [195 163  90]]
#
#  [[188 176 158]
#   [188 176 158]
#   [188 176 158]
#   ...
#   [195 163  90]
#   [195 163  90]
#   [195 163  90]]
#
#  ...
#
#  [[ 33  58 132]
#   [ 33  58 132]
#   [ 32  57 131]
#   ...
#   [ 16  42 109]
#   [ 16  42 109]
#   [ 16  42 109]]
#
#  [[ 33  58 132]
#   [ 33  58 132]
#   [ 32  57 131]
#   ...
#   [ 16  42 109]
#   [ 16  42 109]
#   [ 16  42 109]]
#
#  [[ 33  58 132]
#   [ 32  57 131]
#   [ 32  57 131]
#   ...
#   [ 16  42 109]
#   [ 16  42 109]
#   [ 16  42 109]]]

# %%
cv2_imshow(img/2)
cv2_imshow(img*6)
cv2_imshow(255 - img)
# Out:
# <PIL.Image.Image image mode=RGB size=495x619>
# <PIL.Image.Image image mode=RGB size=495x619>
# <PIL.Image.Image image mode=RGB size=495x619>

# %%
B,G,R = cv2.split(img)

cv2_imshow(B)
cv2_imshow(G)
cv2_imshow(R)
# Out:
# <PIL.Image.Image image mode=L size=495x619>
# <PIL.Image.Image image mode=L size=495x619>
# <PIL.Image.Image image mode=L size=495x619>
